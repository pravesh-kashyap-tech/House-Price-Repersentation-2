# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sales_data.csv")
df
# Out:
#     Area   Price
# 0    750  150000
# 1    800  160000
# 2    950  180000
# 3   1100  200000
# 4   1200  220000
# 5   1350  250000
# 6   1500  270000
# 7   1600  290000
# 8   1750  320000
# 9   1900  350000
# 10  2000  370000
# 11  2200  400000
# 12  2500  450000
# 13  2700  490000
# 14  3000  550000

# %%
print("📊 First 5 Rows of Data:")
print(df.head(), "\n")
# Out:
# 📊 First 5 Rows of Data:
#    Area   Price
# 0   750  150000
# 1   800  160000
# 2   950  180000
# 3  1100  200000
# 4  1200  220000

# %%
print("ℹ️ Dataset Info:")
print(df.info(), "\n")
# Out:
# ℹ️ Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Area    15 non-null     int64
#  1   Price   15 non-null     int64
# dtypes: int64(2)
# memory usage: 372.0 bytes
# None

# %%
print("📈 Summary Statistics:")
print(df.describe(), "\n")
# Out:
# 📈 Summary Statistics:
#               Area          Price
# count    15.000000      15.000000
# mean   1686.666667  310000.000000
# std     695.256034  123577.621645
# min     750.000000  150000.000000
# 25%    1150.000000  210000.000000
# 50%    1600.000000  290000.000000
# 75%    2100.000000  385000.000000
# max    3000.000000  550000.000000

# %%
average_price = df["Price"].mean()
print(f"🔹 Average Land Price: {average_price:.2f}\n")
# Out:
# 🔹 Average Land Price: 310000.00

# %%
plt.figure(figsize=(8, 4))
plt.bar(df["Area"], df["Price"], color="skyblue")
plt.xlabel("Area (sq ft)")
plt.ylabel("Price ($)")
plt.title("Land Price by Area")
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.scatter(df["Area"], df["Price"], color="green", alpha=0.6)
plt.xlabel("Area (sq ft)")
plt.ylabel("Price ($)")
plt.title("Scatter Plot: Area vs Price")
plt.show()

# %%
corr_matrix = df.corr(numeric_only=True)

plt.figure(figsize=(5, 4))
plt.matshow(corr_matrix, cmap="coolwarm", fignum=1)
plt.colorbar(label="Correlation")
plt.xticks(range(len(corr_matrix.columns)), corr_matrix.columns, rotation=45)
plt.yticks(range(len(corr_matrix.columns)), corr_matrix.columns)
plt.title("Correlation Matrix Heatmap (Matplotlib)", pad=20)
plt.show()

# %%
if "Area" in df.columns and "Price" in df.columns:
    correlation = df["Area"].corr(df["Price"])
    print(f"➡️ Correlation between Area and Price: {correlation:.2f}")
    if correlation > 0.7:
        print("➡️ Strong positive relationship: larger areas generally cost more.\n")
    elif correlation > 0.3:
        print("➡️ Moderate positive relationship between area and price.\n")
    else:
        print("➡️ Weak relationship between area and price.\n")

print("➡️ Average price shows the general cost trend.")
print("➡️ Bar chart shows how land prices increase with area.")
print("➡️ Scatter plot confirms relationship between area and price.")
print("➡️ Heatmap provides overall correlation structure.")
# Out:
# ➡️ Correlation between Area and Price: 1.00
# ➡️ Strong positive relationship: larger areas generally cost more.
#
# ➡️ Average price shows the general cost trend.
# ➡️ Bar chart shows how land prices increase with area.
# ➡️ Scatter plot confirms relationship between area and price.
# ➡️ Heatmap provides overall correlation structure.

# %%
df["Area_Range"] = (df["Area"] // 500) * 500   # group areas into 500 sq ft bins
avg_prices = df.groupby("Area_Range")["Price"].mean()

plt.figure(figsize=(8, 4))
avg_prices.plot(kind="bar", color="orange")
plt.xlabel("Area Range (sq ft)")
plt.ylabel("Average Price ($)")
plt.title("Average Price by Area Range")
plt.show()
